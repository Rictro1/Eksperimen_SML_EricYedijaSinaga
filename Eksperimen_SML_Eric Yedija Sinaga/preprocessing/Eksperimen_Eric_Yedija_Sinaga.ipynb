# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset dapat diperoleh dari berbagai sumber, seperti public repositories (*Kaggle*, *UCI ML Repository*, *Open Data*) atau data primer yang Anda kumpulkan sendiri.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
sns.set_theme(style="whitegrid")

BASE_DIR = "/content/Eksperimen_SML_EricSinaga"
WORKFLOW_DIR = os.path.join(BASE_DIR, ".workflow")
PREPROCESSING_DIR = os.path.join(BASE_DIR, "preprocessing")

os.makedirs(BASE_DIR, exist_ok=True)
os.makedirs(WORKFLOW_DIR, exist_ok=True)
os.makedirs(PREPROCESSING_DIR, exist_ok=True)

print("Folder Kriteria 1 berhasil dibuat.")
# Out:
# Folder Kriteria 1 berhasil dibuat.

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
csv_path = "/content/WineQT.csv"

df_raw = pd.read_csv(csv_path)

print("Dataset berhasil dimuat.")
print("Ukuran dataset:", df_raw.shape)

df_raw.head()
# Out:
# Dataset berhasil dimuat.
# Ukuran dataset: (1143, 13)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# ...

# %%
print("Informasi dataset:")
df_raw.info()

print("\nNama kolom:")
print(df_raw.columns.tolist())

print("\nStatistik deskriptif:")
df_raw.describe()
# Out:
# Informasi dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB
#
# Nama kolom:
# ...

# %%
raw_path = os.path.join(BASE_DIR, "winequality_raw.csv")

df_raw.to_csv(raw_path, index=False)

print("Dataset raw berhasil disimpan sebagai:", raw_path)
# Out:
# Dataset raw berhasil disimpan sebagai: /content/Eksperimen_SML_EricSinaga/winequality_raw.csv

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
missing_report = pd.DataFrame({
    "missing_count": df_raw.isnull().sum(),
    "missing_percentage": (df_raw.isnull().sum() / len(df_raw)) * 100
})

missing_report
# Out:
#                       missing_count  missing_percentage
# fixed acidity                     0                 0.0
# volatile acidity                  0                 0.0
# citric acid                       0                 0.0
# residual sugar                    0                 0.0
# chlorides                         0                 0.0
# free sulfur dioxide               0                 0.0
# total sulfur dioxide              0                 0.0
# density                           0                 0.0
# pH                                0                 0.0
# sulphates                         0                 0.0
# alcohol                           0                 0.0
# quality                           0                 0.0
# Id                                0                 0.0

# %%
duplicate_count = df_raw.duplicated().sum()
duplicate_percentage = (duplicate_count / len(df_raw)) * 100

print("Jumlah data duplikat:", duplicate_count)
print("Persentase data duplikat:", round(duplicate_percentage, 2), "%")
# Out:
# Jumlah data duplikat: 0
# Persentase data duplikat: 0.0 %

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df_raw, x="quality")
plt.title("Distribusi Nilai Quality")
plt.xlabel("Quality")
plt.ylabel("Jumlah Data")
plt.show()

df_raw["quality"].value_counts().sort_index()
# Out:
# quality
# 3      6
# 4     33
# 5    483
# 6    462
# 7    143
# 8     16
# Name: count, dtype: int64

# %%
df_eda = df_raw.copy()

if "Id" in df_eda.columns:
    df_eda = df_eda.drop(columns=["Id"])

df_eda["quality_label"] = np.where(df_eda["quality"] >= 7, 1, 0)

df_eda[["quality", "quality_label"]].head()
# Out:
#    quality  quality_label
# 0        5              0
# 1        5              0
# 2        5              0
# 3        6              0
# 4        5              0

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df_eda, x="quality_label")
plt.title("Distribusi Target Biner")
plt.xlabel("Quality Label: 0 = Not Good, 1 = Good")
plt.ylabel("Jumlah Data")
plt.show()

df_eda["quality_label"].value_counts()
# Out:
# quality_label
# 0    984
# 1    159
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 10))

correlation_matrix = df_eda.corr(numeric_only=True)

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %%
target_correlation = correlation_matrix["quality_label"].sort_values(ascending=False)

plt.figure(figsize=(8, 6))
target_correlation.drop("quality_label").plot(kind="barh")
plt.title("Korelasi Fitur terhadap Target Quality Label")
plt.xlabel("Correlation")
plt.ylabel("Feature")
plt.show()

target_correlation
# Out:
# quality_label           1.000000
# quality                 0.720433
# alcohol                 0.403676
# citric acid             0.251146
# sulphates               0.208020
# fixed acidity           0.123212
# residual sugar          0.064145
# free sulfur dioxide    -0.055977
# pH                     -0.073318
# chlorides              -0.103985
# total sulfur dioxide   -0.113373
# density                -0.148670
# volatile acidity       -0.304523
# Name: quality_label, dtype: float64

# %%
numeric_columns = df_eda.select_dtypes(include=["int64", "float64"]).columns.tolist()

df_eda[numeric_columns].hist(figsize=(16, 14), bins=25)
plt.suptitle("Distribusi Fitur Numerik", fontsize=16)
plt.show()

# %%
feature_columns_for_boxplot = [
    col for col in numeric_columns
    if col not in ["quality", "quality_label"]
]

plt.figure(figsize=(16, 10))
df_eda[feature_columns_for_boxplot].boxplot(rot=90)
plt.title("Boxplot Fitur Numerik untuk Deteksi Outlier")
plt.ylabel("Nilai")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_eda, x="quality", y="alcohol")
plt.title("Hubungan Alcohol dengan Quality")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_eda, x="quality", y="sulphates")
plt.title("Hubungan Sulphates dengan Quality")
plt.xlabel("Quality")
plt.ylabel("Sulphates")
plt.show()

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
df = df_raw.copy()

if "Id" in df.columns:
    df = df.drop(columns=["Id"])

print("Ukuran dataset setelah menghapus kolom Id jika ada:", df.shape)
df.head()
# Out:
# Ukuran dataset setelah menghapus kolom Id jika ada: (1143, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# ...

# %%
missing_before = df.isnull().sum().sum()

for col in df.columns:
    if df[col].isnull().sum() > 0:
        if df[col].dtype in ["int64", "float64"]:
            df[col] = df[col].fillna(df[col].median())
        else:
            df[col] = df[col].fillna(df[col].mode()[0])

missing_after = df.isnull().sum().sum()

print("Missing value sebelum handling:", missing_before)
print("Missing value setelah handling:", missing_after)
# Out:
# Missing value sebelum handling: 0
# Missing value setelah handling: 0

# %%
duplicate_before = df.duplicated().sum()

df = df.drop_duplicates().reset_index(drop=True)

duplicate_after = df.duplicated().sum()

print("Duplikat sebelum handling:", duplicate_before)
print("Duplikat setelah handling:", duplicate_after)
print("Ukuran dataset setelah menghapus duplikat:", df.shape)
# Out:
# Duplikat sebelum handling: 125
# Duplikat setelah handling: 0
# Ukuran dataset setelah menghapus duplikat: (1018, 12)

# %%
df["quality_label"] = np.where(df["quality"] >= 7, 1, 0)

print("Distribusi target quality_label:")
print(df["quality_label"].value_counts())

df[["quality", "quality_label"]].head()
# Out:
# Distribusi target quality_label:
# quality_label
# 0    881
# 1    137
# Name: count, dtype: int64
#    quality  quality_label
# 0        5              0
# 1        5              0
# 2        5              0
# 3        6              0
# 4        5              0

# %%
eps = 1e-6

df["alcohol_density_ratio"] = df["alcohol"] / (df["density"] + eps)
df["acid_ratio"] = df["fixed acidity"] / (df["volatile acidity"] + eps)
df["sulfur_ratio"] = df["free sulfur dioxide"] / (df["total sulfur dioxide"] + eps)
df["total_acidity"] = df["fixed acidity"] + df["volatile acidity"] + df["citric acid"]
df["sweetness_acidity_ratio"] = df["residual sugar"] / (df["total_acidity"] + eps)

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality_label  alcohol_density_ratio  acid_ratio  \
# ...

# %%
X = df.drop(columns=["quality", "quality_label"])
y = df["quality_label"]

print("Jumlah fitur:", X.shape[1])
print("Jumlah data:", X.shape[0])

X.head()
# Out:
# Jumlah fitur: 16
# Jumlah data: 1018
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
# ...

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()

X_clipped = X.copy()

for col in numeric_features:
    Q1 = X_clipped[col].quantile(0.25)
    Q3 = X_clipped[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    X_clipped[col] = X_clipped[col].clip(
        lower=lower_bound,
        upper=upper_bound
    )

print("Handling outlier selesai.")
X_clipped.head()
# Out:
# Handling outlier selesai.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
# ...

# %%
scaler = StandardScaler()

X_scaled_array = scaler.fit_transform(X_clipped)

X_scaled = pd.DataFrame(
    X_scaled_array,
    columns=X_clipped.columns
)

X_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.522218          0.944624    -1.372134       -0.700791  -0.267497
# 1      -0.276013          1.957367    -1.372134        0.449332   0.957376
# 2      -0.276013          1.282205    -1.167886       -0.043577   0.623320
# 3       1.816728         -1.418443     1.487350       -0.700791  -0.323173
# 4      -0.522218          0.719570    -1.372134       -0.865094  -0.323173
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.464911             -0.381623  0.602960  1.314390  -0.658956
# 1             0.978486              0.706961  0.057726 -0.727628   0.245364
# 2            -0.052512              0.278125  0.166773 -0.332399   0.019284
# 3             0.153688              0.476049  0.712007 -0.991115  -0.508236
# 4            -0.258712             -0.183699  0.602960  1.314390  -0.658956
#
# ...

# %%
winequality_preprocessing = X_scaled.copy()
winequality_preprocessing["quality_label"] = y.reset_index(drop=True)

print("Ukuran dataset hasil preprocessing:", winequality_preprocessing.shape)

winequality_preprocessing.head()
# Out:
# Ukuran dataset hasil preprocessing: (1018, 17)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.522218          0.944624    -1.372134       -0.700791  -0.267497
# 1      -0.276013          1.957367    -1.372134        0.449332   0.957376
# 2      -0.276013          1.282205    -1.167886       -0.043577   0.623320
# 3       1.816728         -1.418443     1.487350       -0.700791  -0.323173
# 4      -0.522218          0.719570    -1.372134       -0.865094  -0.323173
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.464911             -0.381623  0.602960  1.314390  -0.658956
# 1             0.978486              0.706961  0.057726 -0.727628   0.245364
# 2            -0.052512              0.278125  0.166773 -0.332399   0.019284
# 3             0.153688              0.476049  0.712007 -0.991115  -0.508236
# 4            -0.258712             -0.183699  0.602960  1.314390  -0.658956
#
# ...

# %%
preprocessing_path = os.path.join(
    PREPROCESSING_DIR,
    "winequality_preprocessing.csv"
)

winequality_preprocessing.to_csv(preprocessing_path, index=False)

print("Dataset preprocessing berhasil disimpan sebagai:", preprocessing_path)
# Out:
# Dataset preprocessing berhasil disimpan sebagai: /content/Eksperimen_SML_EricSinaga/preprocessing/winequality_preprocessing.csv

# %%
script_path = os.path.join(PREPROCESSING_DIR, "automate_EricSinaga.py")

script_content = r'''
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
PREPROCESSING_DIR = os.path.join(BASE_DIR, "preprocessing")

RAW_PATH = os.path.join(BASE_DIR, "winequality_raw.csv")
OUTPUT_PATH = os.path.join(PREPROCESSING_DIR, "winequality_preprocessing.csv")

df = pd.read_csv(RAW_PATH)

if "Id" in df.columns:
    df = df.drop(columns=["Id"])

for col in df.columns:
    if df[col].isnull().sum() > 0:
        if df[col].dtype in ["int64", "float64"]:
            df[col] = df[col].fillna(df[col].median())
        else:
            df[col] = df[col].fillna(df[col].mode()[0])

df = df.drop_duplicates().reset_index(drop=True)

df["quality_label"] = np.where(df["quality"] >= 7, 1, 0)

eps = 1e-6

df["alcohol_density_ratio"] = df["alcohol"] / (df["density"] + eps)
df["acid_ratio"] = df["fixed acidity"] / (df["volatile acidity"] + eps)
df["sulfur_ratio"] = df["free sulfur dioxide"] / (df["total sulfur dioxide"] + eps)
df["total_acidity"] = df["fixed acidity"] + df["volatile acidity"] + df["citric acid"]
df["sweetness_acidity_ratio"] = df["residual sugar"] / (df["total_acidity"] + eps)

X = df.drop(columns=["quality", "quality_label"])
y = df["quality_label"]

numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()

X_clipped = X.copy()

for col in numeric_features:
    Q1 = X_clipped[col].quantile(0.25)
    Q3 = X_clipped[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    X_clipped[col] = X_clipped[col].clip(
        lower=lower_bound,
        upper=upper_bound
    )

scaler = StandardScaler()
X_scaled_array = scaler.fit_transform(X_clipped)

X_scaled = pd.DataFrame(
    X_scaled_array,
    columns=X_clipped.columns
)

winequality_preprocessing = X_scaled.copy()
winequality_preprocessing["quality_label"] = y.reset_index(drop=True)

winequality_preprocessing.to_csv(OUTPUT_PATH, index=False)

print("Preprocessing selesai.")
print("File tersimpan di:", OUTPUT_PATH)
'''

with open(script_path, "w") as f:
    f.write(script_content)

print("File automate_EricSinaga.py berhasil dibuat di:", script_path)
# Out:
# File automate_EricSinaga.py berhasil dibuat di: /content/Eksperimen_SML_EricSinaga/preprocessing/automate_EricSinaga.py
